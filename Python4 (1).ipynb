# %%
import pandas as pd
import numpy as np

# %%
df_estudiantes=pd.read_csv('/content/drive/MyDrive/StudentsPerformance (1).csv')
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#operaciones en columnas
#lo primero que debo hacer es elegir la columna que quiero operar, ojala una columna numerica
df_estudiantes['reading score']
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: int64

# %%
#como sumar datos de una columna
df_estudiantes['reading score'].sum()
# Out:
# 69169

# %%
#Como contar datos de una columna
df_estudiantes['reading score'].count()
# Out:
# 1000

# %%
#ejemplo 2
df_estudiantes['gender'].count()
# Out:
# 1000

# %%
#Para calcular el promedio de una columna utilizamos el metodo mean
df_estudiantes['reading score'].mean()
# Out:
# 69.169

# %%
#para calcular la desviacion estandar de una columna uso el metodo std
df_estudiantes['reading score'].std()
# Out:
# 14.60019193725222

# %%
#para ver los valores maximos de una columna uso el metodo max
df_estudiantes['reading score'].max()
# Out:
# 100

# %%
#para ver el valor minimo de una columna uso el metodo min
df_estudiantes['reading score'].min()
# Out:
# 17

# %%
# para ver las medidas de tendencia central de una columna uso el metodo describe
df_estudiantes['reading score'].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
#ahora vamos a realizar operaciones entre filas
df_estudiantes['math score']+ df_estudiantes['reading score']+ df_estudiantes['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
#Asi guardo una nueva colmuna calculada
df_estudiantes['Total']=df_estudiantes['math score']+ df_estudiantes['reading score']+ df_estudiantes['writing score']
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total
# ...

# %%
#Ahora vamos a calcular el promedio de los datos de estas personas
(df_estudiantes['Total'])/3
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: Total, Length: 1000, dtype: float64

# %%
df_estudiantes['PROMEDIO']=(df_estudiantes['Total'])/3
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Asi formateo los numeros para que tenga solo dos decimales
df_estudiantes.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Ahora vamos a contar elementos por valor
len(df_estudiantes['gender'])
# Out:
# 1000

# %%
#Para contar cada uno (cada tipo) uso el metodo value.counts
df_estudiantes['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# para contar la raza y grupos etnicos en este caso
df_estudiantes['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
#Asi puedo calcular el % de aprticipaion de cada elemento
df_estudiantes['race/ethnicity'].value_counts(normalize=True)*100
# Out:
# race/ethnicity
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: proportion, dtype: float64

# %%
# Agrupamos por parental level education
df_estudiantes['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
#Tambien puedo calcular el % de participacion de ese item usando el value count
df_estudiantes['parental level of education'].value_counts(normalize=True)*100
# Out:
# parental level of education
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: proportion, dtype: float64

# %%
#Calcule el % de participacion por genero
df_estudiantes['gender'].value_counts(normalize=True)*100
# Out:
# gender
# female    51.8
# male      48.2
# Name: proportion, dtype: float64

# %%
#Calculo con numero ejemplo con math score
df_estudiantes['math score'].value_counts()
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64

# %%
#Ordenemos los datos por el valor de matematicas en ascendente
df_estudiantes=df_estudiantes.sort_values('math score')
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 458  female        group E           bachelor's degree      standard
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Guardar en CSV en el drive
df_estudiantes.to_csv('organizado_matematicas.csv', index=False)

# %%
# Ahora vamos a organizar de forma descendiente
df_estudiantes.sort_values('math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
# Tambien podemos ordenar los Dataframe no solo por una columna si no por dos, hay que tener en cuenta que organizara por el primer dato y el segundo sera dependiente
df_estudiantes.sort_values(['reading score', 'writing score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 970  female        group D           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Descargar nuevamente
df_estudiantes=df_estudiantes.sort_values(['reading score', 'writing score'], ascending=False)
df_estudiantes.to_csv('organizado_matematicas2.csv', index=False)
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 970  female        group D           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
# De esta manera puedo guardar los datos y sobreescribir sin reusar la variables con el metodo inplace
df_estudiantes.sort_values(['reading score', 'writing score'], ascending=False,
                           inplace=True)

# %%
#Ordenar los valores pero por texto, para eso usaremos la funcion lambda
#Con ella convertimos los valores primero en minuscula y luego ordenamos
df_estudiantes.sort_values('race/ethnicity', ascending=True,
                           key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 837  female        group A                 high school      standard
# 129  female        group A           bachelor's degree      standard
# 467    male        group A                 high school  free/reduced
# 511    male        group A            some high school      standard
# 378  female        group A            some high school      standard
# ..      ...            ...                         ...           ...
# 186    male        group E                 high school      standard
# 968  female        group E          associate's degree      standard
# 269  female        group E                some college  free/reduced
# 926    male        group E          associate's degree  free/reduced
# 881  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...
